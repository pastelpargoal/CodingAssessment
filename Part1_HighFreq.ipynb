# %% [markdown]
# <a href="https://colab.research.google.com/github/pastelpargoal/CodingAssessment/blob/main/Part1_HighFreq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1: High Frequency Survey Checks

# %%
# download necessary packages

# basics
import pandas as pd
import numpy as np

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/pastelpargoal/CodingAssessment/main/survey_results.csv"
surveydata = pd.read_csv(url)
surveydata.head()
# Out:
#    uniqueid     hhid  surveyid  surveyor  surveydate  surveytime  \
# 0         1  1101008       122  Benjamin     9242014        6308
# 1         2  1101015       101     Peter     9132013        7295
# 2         3  1101019       115     Peter    12142014        6339
# 3         4  1101027        84  Benjamin    10172014        7430
# 4         5  1101040        88      Anna     9242014        7551
#
#    survey_complete  superpresent  scrutinizedyn  backcheckedyn  ...  \
# 0                1           0.0              1            0.0  ...
# 1                0           0.0              1            0.0  ...
# 2                1           0.0              1            0.0  ...
# 3                1           0.0              1            0.0  ...
# 4                1           0.0              1            0.0  ...
#
#    theftvictim_2  thanavisityn     thanavisitreason  thanavisitreason_other  \
# 0            NaN           1.0                Other         BATWARE KE LIYE
# ...

# %% [markdown]
# # Survey Duration

# %% [markdown]
# ## a. Calculate the average and median values of time spent surveying, considering only completed surveys.

# %%
surveydata1= surveydata[surveydata.survey_complete==1]
surveydata1.head()
# Out:
#    uniqueid     hhid  surveyid  surveyor  surveydate  surveytime  \
# 0         1  1101008       122  Benjamin     9242014        6308
# 2         3  1101019       115     Peter    12142014        6339
# 3         4  1101027        84  Benjamin    10172014        7430
# 4         5  1101040        88      Anna     9242014        7551
# 5         6  1101044       107      Anna    10202014        5636
#
#    survey_complete  superpresent  scrutinizedyn  backcheckedyn  ...  \
# 0                1           0.0              1            0.0  ...
# 2                1           0.0              1            0.0  ...
# 3                1           0.0              1            0.0  ...
# 4                1           0.0              1            0.0  ...
# 5                1           0.0              1            0.0  ...
#
#    theftvictim_2  thanavisityn     thanavisitreason  thanavisitreason_other  \
# 0            NaN           1.0                Other         BATWARE KE LIYE
# ...

# %%
#surveyAvg =
surveydata1.surveytime.mean()
# Out:
# np.float64(7201.995555555555)

# %%
surveyAvg= float(surveydata1.surveytime.mean())
surveyMedian = surveydata1.surveytime.median()

# %% [markdown]
# # 2. Enumerator Differences

# %% [markdown]
# ## a) Does this average value mask important differences among surveyors? For each surveyor in the dataset, output the average length of time spent surveying, again for only completed surveys.

# %%
totalsurveytime = float(surveydata1.surveytime.sum())
numSurvey = len(surveydata1.surveytime)
average = totalsurveytime/ numSurvey
average
# Out:
# 7201.995555555555

# %% [markdown]
# ## b) Briefly comment on any notable differences.

# %% [markdown]
# ###

# %%
#surveydata1.['survey_complete'].mean
surveyAvg = surveydata1.surveytime.mean()

surveyMedian = surveydata1.surveytime.median()

# %% [markdown]
# # 3. Uniqueness of ID vars

# %% [markdown]
# ## a. Check whether the hhid variable is unique (i.e., each observation represents a distinct household).

# %%
surveydata1.shape
# Out:
# (900, 70)

# %%
surveydata1.hhid.unique()
surveydata1.hhid.nunique()
# Out:
# 897

# %% [markdown]
# ### 897 are unique while 3 are not.

# %% [markdown]
# ## b) If duplicates exist, list the duplicated IDs.

# %%
surveydata1[surveydata1.hhid.duplicated()]
# Out:
#      uniqueid     hhid  surveyid surveyor  surveydate  surveytime  \
# 597       598  1802011       640      Sam     9172013        7098
# 641       642  1807077       981      Sam     8222014        6749
# 679       680  1813023       669     Mary    10292013        6584
#
#      survey_complete  superpresent  scrutinizedyn  backcheckedyn  ...  \
# 597                1           0.0              1            1.0  ...
# 641                1           0.0              1            0.0  ...
# 679                1           0.0              1            0.0  ...
#
#      theftvictim_2  thanavisityn  thanavisitreason  thanavisitreason_other  \
# 597            NaN           2.0               NaN                     NaN
# 641            NaN           2.0               NaN                     NaN
# 679            NaN           2.0               NaN                     NaN
#
#      surveytime2  thanavisitreason_other2  exit  base_age  base_income  \
# ...

# %%
#surveydata1[surveydata1.hhid.drop_duplicates()]
surveydata1.hhid.drop_duplicates()
# Out:
# 0       1101008
# 2       1101019
# 3       1101027
# 4       1101040
# 5       1101044
#          ...
# 995     2024053
# 996     2025012
# 998     2025071
# 999     2025087
# 1000    2025097
# Name: hhid, Length: 897, dtype: int64

# %% [markdown]
# ## c)In a few sentences, describe what steps you might take to investigate or resolve duplicate IDs.

# %% [markdown]
# For now, I would drop duplicates to avoid repeated answers, to have a fair outcome.
